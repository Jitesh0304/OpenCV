# %% [markdown]
# # Code 1

# %%
import cv2
import numpy as np
import time
# import imutils
from imutils import paths

    ## object distance from camera
KNOWN_DISTANCE = 12

    ## object width in real
KNOWN_WIDTH = 3.3

              ## find distance of the object from the camera
def Distance_finder(Focal_length, real_width_object , object_width_in_frame):

    distace = (real_width_object * Focal_length) / object_width_in_frame

    return distace


        ## draw rectangle on the photo
def make_rectangle(event, x, y, flag, parameters):
    
        ## read the image
    image = cv2.imread('jio_fi1.jpeg')
    
        ## because my image size is too big.. thats why i convert the size of image into small size
    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)
    
        ## write the logic of mouse_clicking on the image
        ## when ever i click on the image .... the click position will taken into consider
    if event == cv2.EVENT_LBUTTONDOWN:
        
            ## applend the (x,y) coordinate value of the clicked position
            ## append both values simultaniously .... as a set of value
        list1.append((x,y))
        
            ## resize the image as we did before
        height, width = image.shape[:2]

        desired_size = (width//3, height//3)

        resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)
        
            ## draw a circle on the clicked position
        cv2.circle(resized_img, center =(x, y), radius = 1, color =(0,0,0), thickness = 1)
        
        
            ## if we clicked 2 times or more on the image, if the length of list is 2
        ## if len(list1) % 2 == 0:
        if len(list1) == 2:
            
                ## draw rectanle between last two clicked positions on the image(clicked_1  &  clicked_2)
            cv2.rectangle(resized_img, pt1 = list1[-1], pt2 =list1[-2], color =(0,255,0), thickness =1)
            
                ## calculate the width and height of the rectangle
                ## here we will find the width & height of the object in Pixels (in photo)
            width , height = (list1[-1][0] - list1[-2][0]), (list1[-1][1] - list1[-2][1])
            
                ## calculate the focal length 
                ## (width_of_object in pixels * actual_distance_of_the_object from the camera) / actual width of objext in real
            focalLength = (width * KNOWN_DISTANCE) / KNOWN_WIDTH
            
                ## store the focal_length in a list
            focal_list.append(focalLength)
            
                ## calculate the distance of the object 
            inches = Distance_finder(focalLength, KNOWN_WIDTH, width)
            
                ## display the distance of the screen
            cv2.putText(resized_img, "%.2fcm" % (inches * 2.5), (resized_img.shape[1] - 300, resized_img.shape[0] - 100), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 0), 3)
            
        else:
            cv2.putText(resized_img, "click one more time on the image to calculate the focal length",
                        (resized_img.shape[1] - (resized_img.shape[1] - 10), resized_img.shape[0]- (resized_img.shape[0]- 50)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 2)
            
            ## display the image after calculating the distance
        cv2.imshow('window1',resized_img)
        
        
    ## read the image
image = cv2.imread('jio_fi1.jpeg')

    ## resize the image
height, width = image.shape[:2]
desired_size = (width//3, height//3)
resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)

    ## display the image
cv2.imshow('window1', resized_img)

## derived the list we required
list1 =[]
focal_list = []

    ## call the mouse function
cv2.setMouseCallback('window1', make_rectangle)

cv2.waitKey(0)
cv2.destroyAllWindows()


## The above code is for the referal image
## from the above code we will only consider the focal_length 
## Then we compare that with our new images 


## Looping the file and process each and every image
for imagePath in sorted(paths.list_images('jio')):
    
    image = cv2.imread(imagePath)
    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)
    
    Green = (0,255,0)          
    Red = (0,0,255)
    Black = (255,255,255)
    White = (0,0,0)


                  ## distance estimator fuction
    def Distance_finder(Focal_length, real_width_object , object_width_in_frame):

        distace = (real_width_object * Focal_length) / object_width_in_frame

        return distace


    def make_rectangle(event, x, y, flag, parameters):

        if event == cv2.EVENT_LBUTTONDOWN:

            list1.append((x,y))

            cv2.circle(resized_img, center =(x, y), radius = 1, color =(0,0,0), thickness = 1)


            if len(list1) % 2 == 0:

                cv2.rectangle(resized_img, pt1 = list1[-1], pt2 =list1[-2], color =(0,255,0), thickness =1)

                    ## here we will find the width & height of the object in Pixels (in photo)
                width , height = (list1[-1][0] - list1[-2][0]), (list1[-1][1] - list1[-2][1])

                inches = Distance_finder(int(focal_list[0]), KNOWN_WIDTH, width)

                cv2.putText(resized_img, "%.2fcm" % (inches * 2.5), (list1[-1][0],list1[-1][1]), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
                
            cv2.imshow('window1',resized_img)
        
        

    image = cv2.imread(imagePath)

    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)

    cv2.imshow('window1', resized_img)
    list1 =[]
    cv2.setMouseCallback('window1', make_rectangle)

    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# !pip install imutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25847 sha256=bb185bbb532d6a54649331b09b0d0f4556b6c9127fa1f9aa17b9c14ed8070754
#   Stored in directory: c:\users\jitesh\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %% [markdown]
# # Code 2

# %%
import cv2
import numpy as np
import time
import imutils
from imutils import paths

    ## object distance from camera
KNOWN_DISTANCE = 12

    ## object width in real
KNOWN_WIDTH = 3.3


              ## find distance of the object from the camera
def Distance_finder(Focal_length, real_width_object , object_width_in_frame):

    distace = (real_width_object * Focal_length) / object_width_in_frame

    return distace


        ## draw rectangle on the photo
def make_rectangle(event, x, y, flag, parameters):
    
        ## read the image
    image = cv2.imread('jio_fi1.jpeg')
    
        ## because my image size is too big.. thats why i convert the size of image into small size
    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)
    
        ## write the logic of mouse_clicking on the image
        ## when ever i click on the image .... the click position will taken into consider
    if event == cv2.EVENT_LBUTTONDOWN:
        
            ## applend the (x,y) coordinate value of the clicked position
            ## append both values simultaniously .... as a set of value
        list1.append((x,y))
        
            ## draw a circle on the clicked position
        cv2.circle(resized_img, center =(x, y), radius = 1, color =(0,0,0), thickness = 1)
        
        
            ## if we clicked 2 times or more on the image, if the length of list is 2
                #if len(list1) % 2 == 0:
        if len(list1) == 2:
            
                ## draw rectanle between last two clicked positions on the image(clicked_1  &  clicked_2)
            cv2.rectangle(resized_img, pt1 = list1[-1], pt2 =list1[-2], color =(0,255,0), thickness =1)
            
                ## calculate the width and height of the rectangle
            width , height = (list1[-1][0] - list1[-2][0]), (list1[-1][1] - list1[-2][1])
            
                ## calculate the focal length 
                ## (width_of_object in pixels * actual_distance_of_the_object from the camera) / actual width of objext in real
            focalLength = (width * KNOWN_DISTANCE) / KNOWN_WIDTH
            
                ## store the focal_length in a list
            focal_list.append(focalLength)
            
                ## calculate the distance of the object (call the function that we have derive before for the distance)
            inches = Distance_finder(focalLength, KNOWN_WIDTH, width)
            
                ## display the distance of the screen
            cv2.putText(resized_img, "%.2fcm" % (inches * 2.5), (resized_img.shape[1] - 300, resized_img.shape[0] - 100), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 0), 3)
            
                    
        else:
            cv2.putText(resized_img, "click one more time on the image to calculate the focal length",
                        (resized_img.shape[1] - (resized_img.shape[1] - 10), resized_img.shape[0]- (resized_img.shape[0]- 50)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 2)
            
            
            
            ## display the image after calculating the distance
        cv2.imshow('window1',resized_img)
        
        
    ## read the image
image = cv2.imread('jio_fi1.jpeg')

    ## resize the image
height, width = image.shape[:2]
desired_size = (width//3, height//3)
resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)

    ## display the image
cv2.imshow('window1', resized_img)

## derived the list we required
list1 =[]
focal_list = []

    ## call the mouse function
cv2.setMouseCallback('window1', make_rectangle)

cv2.waitKey(0)
cv2.destroyAllWindows()


## The above code is for the referal image
## from the above code we will only consider the focal_length 
## Then we take that focal_length and calculate the distance of object in our new images 


## Looping the file and process each and every image
for imagePath in sorted(paths.list_images('jio')):
    
    image = cv2.imread(imagePath)
    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)
    
    Green = (0,255,0)          
    Red = (0,0,255)
    Black = (255,255,255)
    White = (0,0,0)


                  ## distance estimator fuction
    def Distance_finder(Focal_length, real_width_object , object_width_in_frame):

        distace = (real_width_object * Focal_length) / object_width_in_frame

        return distace


    def make_rectangle(event, x, y, flag, parameters):
        
        image = cv2.imread(imagePath)
        height, width = image.shape[:2]
        desired_size = (width//3, height//3)
        resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)

        if event == cv2.EVENT_LBUTTONDOWN:

            list1.append((x,y))

            cv2.circle(resized_img, center =(x, y), radius = 1, color =(0,0,0), thickness = 1)


            if len(list1) % 2 == 0:

                cv2.rectangle(resized_img, pt1 = list1[-1], pt2 =list1[-2], color =(0,255,0), thickness =1)

                width , height = (list1[-1][0] - list1[-2][0]), (list1[-1][1] - list1[-2][1])

                inches = Distance_finder(int(focal_list[0]), KNOWN_WIDTH, width)

                cv2.putText(resized_img, "%.2fcm" % (inches * 2.5), (list1[-1][0],list1[-1][1]), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
                
            cv2.imshow('window1',resized_img)
        
        

    image = cv2.imread(imagePath)

    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)

    cv2.imshow('window1', resized_img)
    list1 =[]
    cv2.setMouseCallback('window1', make_rectangle)

    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# # Distance of multiple objects from one image

# %%
import cv2
import numpy as np
import time
import imutils
from imutils import paths

    ## object distance from camera
KNOWN_DISTANCE = 12

    ## object width in real
KNOWN_WIDTH = 3.3


              ## find distance of the object from the camera
def Distance_finder(Focal_length, real_width_object , object_width_in_frame):

    distace = (real_width_object * Focal_length) / object_width_in_frame

    return distace


        ## draw rectangle on the photo
def make_rectangle(event, x, y, flag, parameters):
    
        ## read the image
    image = cv2.imread('jio_fi1.jpeg')
    
        ## because my image size is too big.. thats why i convert the size of image into small size
    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)
    
        ## write the logic of mouse_clicking on the image
        ## when ever i click on the image .... the click position will taken into consider
    if event == cv2.EVENT_LBUTTONDOWN:
        
            ## applend the (x,y) coordinate value of the clicked position
            ## append both values simultaniously .... as a set of value
        list1.append((x,y))
        
            ## draw a circle on the clicked position
        cv2.circle(resized_img, center =(x, y), radius = 1, color =(0,0,0), thickness = 1)
        
        
            ## if we clicked 2 times or more on the image, if the length of list is 2
                #if len(list1) % 2 == 0:
        if len(list1) == 2:
            
                ## draw rectanle between last two clicked positions on the image(clicked_1  &  clicked_2)
            cv2.rectangle(resized_img, pt1 = list1[-1], pt2 =list1[-2], color =(0,255,0), thickness =1)
            
                ## calculate the width and height of the rectangle
            width , height = (list1[-1][0] - list1[-2][0]), (list1[-1][1] - list1[-2][1])
            
                ## calculate the focal length 
                ## (width_of_object in pixels * actual_distance_of_the_object from the camera) / actual width of objext in real
            focalLength = (width * KNOWN_DISTANCE) / KNOWN_WIDTH
            
                ## store the focal_length in a list
            focal_list.append(focalLength)
            
                ## calculate the distance of the object (call the function that we have derive before for the distance)
            inches = Distance_finder(focalLength, KNOWN_WIDTH, width)
            
                ## display the distance of the screen
            cv2.putText(resized_img, "%.2fcm" % (inches * 2.5), (resized_img.shape[1] - 300, resized_img.shape[0] - 100), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 0, 0), 3)
            
                    
        else:
            cv2.putText(resized_img, "click one more time on the image to calculate the focal length",
                        (resized_img.shape[1] - (resized_img.shape[1] - 10), resized_img.shape[0]- (resized_img.shape[0]- 50)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 2)
            
            
            
            ## display the image after calculating the distance
        cv2.imshow('window1',resized_img)
        
        
    ## read the image
image = cv2.imread('jio_fi1.jpeg')

    ## resize the image
height, width = image.shape[:2]
desired_size = (width//3, height//3)
resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)

    ## display the image
cv2.imshow('window1', resized_img)

## derived the list we required
list1 =[]
focal_list = []

    ## call the mouse function
cv2.setMouseCallback('window1', make_rectangle)

cv2.waitKey(0)
cv2.destroyAllWindows()


## The above code is for the referal image
## from the above code we will only consider the focal_length 
## Then we take that focal_length and calculate the distance of object in our new images 


## Looping the file and process each and every image
for imagePath in sorted(paths.list_images('jio')):
    
    image = cv2.imread(imagePath)
    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)
    
    Green = (0,255,0)          
    Red = (0,0,255)
    Black = (255,255,255)
    White = (0,0,0)


                  ## distance estimator fuction
    def Distance_finder(Focal_length, real_width_object , object_width_in_frame):

        distace = (real_width_object * Focal_length) / object_width_in_frame

        return distace


    def make_rectangle(event, x, y, flag, parameters):
        
        if event == cv2.EVENT_LBUTTONDOWN:

            list1.append((x,y))

            cv2.circle(resized_img, center =(x, y), radius = 1, color =(0,0,0), thickness = 1)


            if len(list1) % 2 == 0:

                cv2.rectangle(resized_img, pt1 = list1[-1], pt2 =list1[-2], color =(0,255,0), thickness =1)

                width , height = (list1[-1][0] - list1[-2][0]), (list1[-1][1] - list1[-2][1])

                inches = Distance_finder(int(focal_list[0]), KNOWN_WIDTH, width)

                cv2.putText(resized_img, "%.2fcm" % (inches * 2.5), (list1[-1][0],list1[-1][1]), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
                
        cv2.imshow('window1',resized_img)
        
        

    image = cv2.imread(imagePath)

    height, width = image.shape[:2]
    desired_size = (width//3, height//3)
    resized_img = cv2.resize(image, desired_size, interpolation = cv2.INTER_LINEAR)

    cv2.imshow('window1', resized_img)
    list1 =[]
    cv2.setMouseCallback('window1', make_rectangle)

    cv2.waitKey(0)
    cv2.destroyAllWindows()
